# %%
import requests
import pandas as pd
import os
from datetime import datetime
import re

# %% [markdown]
# # Download data

# %% [markdown]
# ## Image data

# %%
url_images = 'http://datamall2.mytransport.sg/ltaodataservice/Traffic-Imagesv2'
headers = {'AccountKey' : os.environ["LTA_ACCOUNT_KEY"]}
images = requests.get(url_images, headers = headers).json()
# Out:
# {'odata.metadata': 'http://datamall2.mytransport.sg/ltaodataservice/$metadata#Traffic-Imagesv2',
#  'value': [{'CameraID': '1001',
#    'Latitude': 1.29531332,
#    'Longitude': 103.871146,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1001_2303_20221116230519_102985.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150519Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=d4f9008d8a8cb4d8f45d87cc9cf2e57e659c9529b2f2083c3efdad414b76c545'},
#   {'CameraID': '1002',
#    'Latitude': 1.319541067,
#    'Longitude': 103.8785627,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1002_2258_20221116230519_539956.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150519Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=86a28e9f2c5a9cb1add1a9431b1032444afadb61ab0f5735da22fc359c8b6999'},
#   {'CameraID': '1003',
#    'Latitude': 1.323957439,
#    'Longitude': 103.8728576,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1003_2258_20221116230519_565210.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150519Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=2fee99615a21de28dd9efd72740ed6bd1fa413f9205e9b7a5411392e9dba4541'},
#   {'CameraID': '1004',
#    'Latitude': 1.319535712,
#    'Longitude': 103.8750668,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1004_2258_20221116230519_505398.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150519Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=4313627a698df43331a657270365e25d41c07f750fa3d17e8270566323177096'},
#   {'CameraID': '1005',
#    'Latitude': 1.363519886,
#    'Longitude': 103.905394,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1005_2258_20221116230516_101534.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150519Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=81db6dd4fb98298096fdbdd3d780b4751ba4f7f1976ceff465071b15a65d1585'},
#   {'CameraID': '1006',
#    'Latitude': 1.357098686,
#    'Longitude': 103.902042,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1006_2258_20221116230504_531005.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150516Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=4de54eb05c747b3a7bcdb7e9fa560287e87cadea2f4e2fadd39853ba5ac1cca4'},
#   {'CameraID': '1501',
#    'Latitude': 1.27414394350065,
#    'Longitude': 103.851316802547,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1501_2258_20221116230519_485251.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150519Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=fbaac31d0a7a1b84613a72cbf73d33906df0c50eb670482f6a08ac08f53793ca'},
#   {'CameraID': '1502',
#    'Latitude': 1.27135090682664,
#    'Longitude': 103.861828440597,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1502_2258_20221116230519_100485.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150519Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=e5ec7265ef8f95fcd8c33e335d2d70e7c8534d6556fdd9e984564232ed1ec164'},
#   {'CameraID': '1503',
#    'Latitude': 1.27066408655104,
#    'Longitude': 103.856977943394,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1503_2258_20221116230519_102505.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150519Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=7a6631c3f10e5b2adebe2a63bd1bfd3cee95842de2e9295215dd8f74780afed7'},
#   {'CameraID': '1504',
#    'Latitude': 1.29409891409364,
#    'Longitude': 103.876056196568,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1504_2258_20221116230519_994897.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150519Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=9b7aa64cdda6a0a27860bb83a14bc732665034b6c91082206e7b06234739538f'},
#   {'CameraID': '1505',
#    'Latitude': 1.2752977149006,
#    'Longitude': 103.866390381759,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1505_2258_20221116230519_101975.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150519Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=5656792998c223d4f6e63521c36852377c5e8765a373a3dbfc44e321bbb40609'},
#   {'CameraID': '1701',
#    'Latitude': 1.323604823,
#    'Longitude': 103.8587802,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1701_2304_20221116230630_485510.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150632Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=e5049d1eef78b84572c0963b26f9547de080740c5703513781e5a57ea04d5a68'},
#   {'CameraID': '1702',
#    'Latitude': 1.34355015,
#    'Longitude': 103.8601984,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1702_2304_20221116230632_559956.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150636Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=6e1014090372de5c94b7b59f1949745d3922854c19c70d28930965d2a9b7b92b'},
#   {'CameraID': '1703',
#    'Latitude': 1.32814722194857,
#    'Longitude': 103.862203282048,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1703_2304_20221116230636_535550.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150638Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=4cd308474ed4c4ee4062903f7e3a894be0084e709bb372e86f245bd240239bda'},
#   {'CameraID': '1704',
#    'Latitude': 1.28569398886979,
#    'Longitude': 103.837524510188,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1704_2304_20221116230638_564910.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150641Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=fed7be5ad6793cbd7a6dd89acbf74824c2965248b170240e43beba603b222478'},
#   {'CameraID': '1705',
#    'Latitude': 1.375925022,
#    'Longitude': 103.8587986,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1705_2304_20221116230641_100975.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150642Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=aaef38dcb9111121706fcc48e29aac999dc4b7c430cf5cc2de658abbca7debb8'},
#   {'CameraID': '1706',
#    'Latitude': 1.38861,
#    'Longitude': 103.85806,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1706_2304_20221116230537_979710.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150554Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=6bd2591a4bc1cfeae409dc28db04c26db5d7a67d59cde36f50077c58d1b9b265'},
#   {'CameraID': '1707',
#    'Latitude': 1.28036584335876,
#    'Longitude': 103.830451146503,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1707_2304_20221116230554_545556.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150554Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=7ee2cc51529469f53cd1b51bb568cf0c6ccbfac100444d88510fb24fd7467776'},
#   {'CameraID': '1709',
#    'Latitude': 1.31384231654635,
#    'Longitude': 103.845603032574,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1709_2304_20221116230554_491014.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150555Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=be7ddce2fb49b5c56d31e41ecb69dc7b9b33057128b8f9b353c43d61e5f92e28'},
#   {'CameraID': '1711',
#    'Latitude': 1.35296,
#    'Longitude': 103.85719,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/1711_2303_20221116230555_555099.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150618Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=5375b6d84d9893bbca335b018f8aaccc77e6e21cb57dd22c1867fac2d91d8a87'},
#   {'CameraID': '2701',
#    'Latitude': 1.447023728,
#    'Longitude': 103.7716543,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/2701_2304_20221116230618_525249.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150630Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=563983efe895795a7a134010442b0a8aa9ad222e75ec3276bfa39761e16615c4'},
#   {'CameraID': '2702',
#    'Latitude': 1.445554109,
#    'Longitude': 103.7683397,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/2702_2304_20221116230504_509854.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150504Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=3aa64d7168e0c943dd94994fd38e2a1d9568856e584d2d3f82c885b5bcf159c7'},
#   {'CameraID': '2703',
#    'Latitude': 1.35047790791386,
#    'Longitude': 103.791033581325,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/2703_2304_20221116230504_529897.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150520Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=5dc996ce0c074165c223ea02f5f90e43555b54d9b088d609e0a05079249fcc86'},
#   {'CameraID': '2704',
#    'Latitude': 1.429588536,
#    'Longitude': 103.769311,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/2704_2304_20221116230520_575610.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150528Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=cfee3d3f88f012480823902a153c6092154e5ff1ef4196fd1c7c4335bf8e7824'},
#   {'CameraID': '2705',
#    'Latitude': 1.36728572,
#    'Longitude': 103.7794698,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/2705_2303_20221116230528_979898.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150530Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=ddde7a5b7764b276a5b755a0980b33c997641a2dac403888d6edc0f257c33b7a'},
#   {'CameraID': '2706',
#    'Latitude': 1.414142,
#    'Longitude': 103.771168,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/2706_2304_20221116230530_489853.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150531Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=c89c6ff314ddacb14bf282b3dbda77337d40ce0d655fedbed1977ada60431b8e'},
#   {'CameraID': '2707',
#    'Latitude': 1.3983,
#    'Longitude': 103.774247,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/2707_2304_20221116230531_102565.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150533Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=f71cd498aab0eceda1e5b8da083650d779999b0029f095d4673a3da831a03b64'},
#   {'CameraID': '2708',
#    'Latitude': 1.3865,
#    'Longitude': 103.7747,
# ...
#   {'CameraID': '8702',
#    'Latitude': 1.39059,
#    'Longitude': 103.7717,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/8702_2304_20221116230558_495610.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150558Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=3e195f3a6abd1cc9f6f11af98e8925288b68a6522d77e1a0d5f55abc2de97610'},
#   {'CameraID': '8704',
#    'Latitude': 1.3899,
#    'Longitude': 103.74843,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/8704_2304_20221116230558_495153.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150600Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=79a6b232280c36aa73a7b142ec3e2848ff6a073a3584c80327607f397bb06045'},
#   {'CameraID': '8706',
#    'Latitude': 1.3664,
#    'Longitude': 103.70899,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/8706_2303_20221116230600_975751.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150610Z&X-Amz-SignedHeaders=host&X-Amz-Expires=599&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=0cb960598687d4fffdb43f4a0ca6aed2a9380c8279949644a778c21b58deabb8'},
#   {'CameraID': '9701',
#    'Latitude': 1.39466333,
#    'Longitude': 103.83474601,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/9701_2304_20221116230519_571014.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150520Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=f9a67fefe75f00fa50855833a0c6822f9fde273825844a6ed19f33c60f51c265'},
#   {'CameraID': '9702',
#    'Latitude': 1.39474081,
#    'Longitude': 103.81797086,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/9702_2303_20221116230520_999956.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150523Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=64671dd3062d51896b25bc4af49842980f17b0e8d9cf2e2788b13b89c473fc05'},
#   {'CameraID': '9703',
#    'Latitude': 1.422857,
#    'Longitude': 103.773005,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/9703_2304_20221116230523_565456.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150524Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=541064a8f0831f6189176eb8b83e5e275b4ce591ca0ee0b3a582b7fabe5ac202'},
#   {'CameraID': '9704',
#    'Latitude': 1.42214311,
#    'Longitude': 103.79542062,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/9704_2303_20221116230524_515097.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150527Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=6fa2c71008fd628b926c1f50b8582a378249c5b207824fc18cab9a99c2b70248'},
#   {'CameraID': '9705',
#    'Latitude': 1.42627712,
#    'Longitude': 103.78716637,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/9705_2304_20221116230527_102101.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150540Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=c28c34968a97291867d6247ab1c4f02f64de20e06dd669870fde00f987336800'},
#   {'CameraID': '9706',
#    'Latitude': 1.41270056,
#    'Longitude': 103.80642712,
#    'ImageLink': 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-16/23-05/9706_2304_20221116230540_555148.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEA4aDmFwLXNvdXRoZWFzdC0xIkgwRgIhAKy9fmLkZ%2FCD6srGlKx%2FHQHNKM1YXLWnkecmKi%2FriQKDAiEA1ubwLtJCz4Z2ZQqiCfGfQ8HQQ5x9BfVs%2F2kUc6REE0Iq2wQIFxADGgwzNDA2NDUzODEzMDQiDOzyrDdaqjzu2Y2ULyq4BPpgN8mJ8uFs1fzk3ypuGaq4rAXxw9g5vSOUkrIQtSsqig7J94JyH7Pr%2F3CeB6a5zxxOfMwCmY5B%2BJnFCU8Y0CvHhfXsYC8F6fmxWSmIGT4bkStA5abKD0ZVJAyvNr7cWmKKH9Oz7RFXz2Hz5wIZCel8Vld5kMowhpQa6JMcyWO8EVAJj45J72rm%2FRhmxfs4NG5Jx%2BpIJoQdxcJuLgrwUlBDPjLyWE80lw6hsT1zfaQ93KnBlJXYGP4yEPx5Tm03ACH6pKqYNSbPpgUaoYr93AHNP5eY%2FzcfbRhnoyGfu8nQOzJP6NtGKrGI%2FixRxviebLqjI69M7RvPbUmxtic1ewADXoIQVabr6fQ64KDRQPH3ZV6ElUdbVU%2B0qOIPewnIMm5EtVwrGkiul%2FE7G4UvNZVpW0xUAtPhCKKcQ4pie2ocUkQClc%2BGFXvCmGN1468wxwajTw2Z%2Bh7UzDY48xiZjrxNnkXzQxTEhg3Asi7s%2FdgL4n9l8oWcme4swp2vpY%2FQKxqColFLUCkl%2FCSr1MTVAxDgDUvBfitFg6sAk1SFEoYvceHMWz%2F6%2FTh8%2F4kYtbZ0JT3IGHI5Gia7OyRwCyjDqHIjtGFnOZFzUyoDfOcsw%2FozINmTFh7UAL3mmLuenjAUrNQLFwzQdex5OOTzmdCENt6dQdmOgbf2eXJ8piK4FnRN7hh2vlxU%2BrFu15snMFaJCYyB0r0Lc3QK3JC0%2BckUIhaqleHYG36Put7wxCEyYDDhQjkI96pSSKYw4NnTmwY6qAGbqdqox7dI4p9vDx%2B5ZfNeNwU0S3xmKspkCLxbWh6KIzJtekk8lcK8SAfjytvFxh7ROhe%2BfJjUu6IP2%2BwFHJUTVrCHS1DguPP7R7dObEX5TSHNpKY3hGLAAmufqzXqw9c6Q6YVcdgMh1SzKdeAL2WeuCjA7bDw98tmMlWvCVux0pYI5yrZqEOs%2BLBFHYrXpha0sHAuQy89jjMPEE4zBK1ha2yfVsDuF8w%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221116T150548Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4BDAR4W56%2F20221116%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=a4ba979236a9da095baebd71d888b314d8b3522ae4386dab40e8bd25283bfbfa'}]}

# %%
type(images)
# Out:
# dict

# %%
filename_regex = re.compile(r'/([\d_]+.jpg)')

for camera in images['value']:
    url = camera['ImageLink']
    # Make filename from imagelink URL which contains camera ID, date and time of image
    filename = os.path.join(os.path.expanduser(os.environ.get("LOCAL_DATA_PATH")), 
                            'data-images', 
                            re.findall(filename_regex, url)[0]) 
    response = requests.get(url)
    with open(filename, 'wb') as f:
        f.write(response.content)

# %%
url_speeds = 'http://datamall2.mytransport.sg/ltaodataservice/TrafficSpeedBandsv2'
speeds = requests.get(url_speeds, headers = headers).json()
speedsdata = [pd.DataFrame(speeds['value']).set_index('LinkID')]
for skip in range(500,59500,500):
    new_speeds = requests.get(url_speeds, headers = headers, params = {'$skip': f'{skip}'}).json()
    speedsdata.append(pd.DataFrame(new_speeds['value']).set_index('LinkID'))
speedsdf = pd.concat(speedsdata)
filename = os.path.join(os.path.expanduser(os.environ.get("LOCAL_DATA_PATH")), 
                        'data-speeds', 
                        datetime.now().strftime('%Y-%m-%d_%H%M') + 'speed.csv')
speedsdf.to_csv(filename)

# %%
len(speedsdf)
# Out:
# 59006

# %% [markdown]
# # Cleaning & Matching

# %%
imagesdf = pd.DataFrame(images['value']).set_index('CameraID')

# %%
speedsdf[['lat1', 'long1', 'lat2', 'long2']] = speedsdf['Location'].str.split(expand = True)

# %%
speedsdf[['lat1', 'long1', 'lat2', 'long2']] = speedsdf[['lat1', 'long1', 'lat2', 'long2']].apply(pd.to_numeric)

# %%
# speedsdf.loc[speedsdf['lat2'] < speedsdf['lat1'], ['lat1', 'lat2']] = speedsdf.loc[speedsdf['lat2'] < speedsdf['lat1'], ['lat2', 'lat1']].values

# %% [markdown]
# # Check if speed exists for each camera

# %%
imagesdf['speeds'] = None

# %% [markdown]
# TODO: make this more efficient by sorting, if need to do multiple times

# %%
# %%time
for cameraindex, cameradata in imagesdf.iterrows():
    for speedindex, speeddata in speedsdf.iterrows():
        if (((speeddata['lat1'] <= cameradata['Latitude'] <= speeddata['lat2'])
             or (speeddata['lat1'] >= cameradata['Latitude'] >= speeddata['lat2']))
            and ((speeddata['long1'] <= cameradata['Longitude'] <= speeddata['long2'])
                 or (speeddata['long1'] >= cameradata['Longitude'] >= speeddata['long2']))):
            print('found')
            if imagesdf.at[cameraindex,'speeds']:
                imagesdf.at[cameraindex, 'speeds'].append(speedindex)
            else:
                imagesdf.at[cameraindex, 'speeds'] = [speedindex]
            print(imagesdf.at[cameraindex, 'speeds'])
# Out:
# found
# ['103100098']
# found
# ['103100098', '103100099']
# found
# ['107002716']
# found
# ['107002716', '107002900']
# found
# ['107002880']
# found
# ['108002954']
# found
# ['108002954', '108002955']
# found
# ['113000212']
# found
# ['113000292']
# found
# ['113000192']
# found
# ['113000260']
# found
# ['103055618']
# found
# ['103055618', '103055619']
# found
# ['103055618', '103055619', '112000000']
# found
# ['104005996']
# found
# ['116000948']
# found
# ['116000948', '116000976']
# found
# ['103104150']
# found
# ['103104150', '103104151']
# found
# ['103115296']
# found
# ['103013056']
# found
# ['103013056', '103061773']
# found
# ['103013056', '103061773', '103103406']
# found
# ['103013056', '103061773', '103103406', '103103407']
# found
# ['103013056', '103061773', '103103406', '103103407', '116000006']
# found
# ['103013056', '103061773', '103103406', '103103407', '116000006', '116000007']
# found
# ['103066482']
# found
# ['103066482', '103066483']
# found
# ['103066482', '103066483', '103116220']
# found
# ['103066670']
# found
# ['103066670', '103066671']
# found
# ['103066670', '103066671', '103104628']
# found
# ['103104640']
# found
# ['103065438']
# found
# ['103065438', '103065439']
# found
# ['103065438', '103065439', '103110492']
# found
# ['103064922']
# found
# ['103064922', '103064923']
# found
# ['103064922', '103064923', '103095272']
# found
# ['103022252']
# found
# ['103022252', '103086770']
# found
# ['103022252', '103086770', '103086771']
# found
# ['103022252', '103086770', '103086771', '103103418']
# found
# ['103022252', '103086770', '103086771', '103103418', '103103419']
# found
# ['103103462']
# found
# ['103103462', '103103463']
# found
# ['103011396']
# found
# ['104002514']
# found
# ['104002514', '104002515']
# found
# ['104002514', '104002515', '106004424']
# found
# ['103075554']
# found
# ['103075554', '103075555']
# found
# ['103075554', '103075555', '103100012']
# found
# ['103055426']
# found
# ['103055426', '103055427']
# found
# ['103103790']
# found
# ['103103790', '103103791']
# found
# ['103103790', '103103791', '103106416']
# found
# ['103103590']
# found
# ['103103590', '103103591']
# found
# ['103067426']
# found
# ['103067426', '103067427']
# found
# ['103103758']
# found
# ['103103758', '103103759']
# found
# ['103105574']
# found
# ['103105574', '103105575']
# found
# ['103110550']
# found
# ['103110550', '103110551']
# found
# ['103103074']
# found
# ['103103074', '103103075']
# found
# ['104005389']
# found
# ['104005389', '104008602']
# found
# ['104005389', '104008602', '104008603']
# found
# ['108002950']
# found
# ['108002950', '108002951']
# found
# ['112000460']
# found
# ['104005629']
# found
# ['104006048']
# found
# ['104006048', '104006156']
# found
# ['104006048', '104006156', '104008722']
# found
# ['104006048', '104006156', '104008722', '104008723']
# found
# ['103016354']
# found
# ['103016354', '103016355']
# found
# ['108001532']
# found
# ['103080124']
# found
# ['103080124', '103102442']
# found
# ['103080124', '103102442', '103102443']
# found
# ['103046838']
# found
# ['103046838', '103046839']
# found
# ['103055122']
# found
# ['103055122', '103055123']
# found
# ['103055122', '103055123', '103102420']
# found
# ['103066964']
# found
# ['103066964', '103104776']
# found
# ['103042174']
# found
# ['103042174', '103042175']
# found
# ['103042174', '103042175', '103099677']
# found
# ['103040776']
# found
# ['103040776', '103067190']
# found
# ['103040776', '103067190', '103067191']
# found
# ['103040776', '103067190', '103067191', '103114918']
# found
# ['103040776', '103067190', '103067191', '103114918', '103114919']
# found
# ['103103452']
# found
# ['103063616']
# found
# ['103063616', '103103526']
# found
# ['103063616', '103103526', '103103527']
# found
# ['103063616', '103103526', '103103527', '103115093']
# found
# ['103064934']
# found
# ['103064934', '103064935']
# found
# ['103064934', '103064935', '103103352']
# found
# ['103064934', '103064935', '103103352', '103107240']
# found
# ['103040960']
# found
# ['103040960', '103061402']
# found
# ['103040960', '103061402', '103061403']
# found
# ['103048325']
# found
# ['103048325', '103056890']
# found
# ['103048325', '103056890', '103056891']
# found
# ['103057028']
# found
# ['103057028', '103066584']
# found
# ['103057028', '103066584', '115000412']
# found
# ['103057028', '103066584', '115000412', '115000528']
# found
# ['103054904']
# found
# ['103116278']
# found
# ['103116278', '103116279']
# found
# ['103045528']
# found
# ['103053952']
# found
# ['103053952', '103053964']
# found
# ['103053952', '103053964', '109002188']
# found
# ['103104270']
# found
# ['103104270', '103104271']
# found
# ['103104226']
# found
# ['103104226', '103104227']
# found
# ['103055720']
# found
# ['103055720', '106003820']
# found
# ['104006714']
# found
# ['104006714', '104006715']
# found
# ['104006714', '104006715', '106003612']
# found
# ['103035560']
# found
# ['103055798']
# found
# ['103055798', '103055799']
# found
# ['103055798', '103055799', '107001442']
# found
# ['103055798', '103055799', '107001442', '107001443']
# CPU times: user 4min 20s, sys: 110 ms, total: 4min 20s
# Wall time: 4min 20s

# %%
imagesdf[imagesdf['speeds'].notnull()]
# Out:
#           Latitude   Longitude  \
# CameraID
# 1001      1.295313  103.871146
# 1003      1.323957  103.872858
# 1004      1.319536  103.875067
# 1006      1.357099  103.902042
# 1501      1.274144  103.851317
# ...            ...         ...
# 9702      1.394741  103.817971
# 9703      1.422857  103.773005
# 9704      1.422143  103.795421
# 9705      1.426277  103.787166
# 9706      1.412701  103.806427
#
#                                                   ImageLink  \
# CameraID
# 1001      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 1003      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 1004      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 1006      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 1501      https://dm-traffic-camera-itsc.s3.ap-southeast...
# ...                                                     ...
# 9702      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 9703      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 9704      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 9705      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 9706      https://dm-traffic-camera-itsc.s3.ap-southeast...
#
#                                                 speeds
# CameraID
# 1001                            [103100098, 103100099]
# 1003                            [107002716, 107002900]
# 1004                                       [107002880]
# 1006                            [108002954, 108002955]
# 1501                                       [113000212]
# ...                                                ...
# 9702                            [103104226, 103104227]
# 9703                            [103055720, 106003820]
# 9704                 [104006714, 104006715, 106003612]
# 9705                                       [103035560]
# 9706      [103055798, 103055799, 107001442, 107001443]
#
# [61 rows x 4 columns]

# %%
camera_speed_map = {}
for index, camera in imagesdf.iterrows():
    camera_speed_map[index] = camera['speeds']

# %%
camera_speed_map
# Out:
# {'1001': ['103100098', '103100099'],
#  '1002': None,
#  '1003': ['107002716', '107002900'],
#  '1004': ['107002880'],
#  '1005': None,
#  '1006': ['108002954', '108002955'],
#  '1501': ['113000212'],
#  '1502': ['113000292'],
#  '1503': None,
#  '1504': ['113000192'],
#  '1505': ['113000260'],
#  '1701': None,
#  '1702': ['103055618', '103055619', '112000000'],
#  '1703': ['104005996'],
#  '1704': ['116000948', '116000976'],
#  '1705': ['103104150', '103104151'],
#  '1706': ['103115296'],
#  '1707': ['103013056',
#   '103061773',
#   '103103406',
#   '103103407',
#   '116000006',
#   '116000007'],
#  '1709': None,
#  '1711': None,
#  '2701': None,
#  '2702': None,
#  '2703': ['103066482', '103066483', '103116220'],
#  '2704': ['103066670', '103066671', '103104628'],
#  '2705': None,
#  '2706': None,
#  '2707': None,
#  '2708': ['103104640'],
#  '3702': ['103065438', '103065439', '103110492'],
#  '3704': None,
#  '3705': ['103064922', '103064923', '103095272'],
#  '3793': ['103022252', '103086770', '103086771', '103103418', '103103419'],
#  '3795': None,
#  '3796': ['103103462', '103103463'],
#  '3797': ['103011396'],
#  '3798': None,
#  '4701': None,
#  '4702': ['104002514', '104002515', '106004424'],
#  '4703': None,
#  '4704': ['103075554', '103075555', '103100012'],
#  '4705': None,
#  '4706': ['103055426', '103055427'],
#  '4707': ['103103790', '103103791', '103106416'],
#  '4708': ['103103590', '103103591'],
#  '4709': ['103067426', '103067427'],
#  '4710': ['103103758', '103103759'],
#  '4712': None,
#  '4713': None,
#  '4714': ['103105574', '103105575'],
#  '4716': None,
#  '4798': None,
#  '4799': None,
#  '5794': ['103110550', '103110551'],
#  '5795': ['103103074', '103103075'],
#  '5797': ['104005389', '104008602', '104008603'],
#  '5798': ['108002950', '108002951'],
#  '5799': ['112000460'],
#  '6701': ['104005629'],
#  '6703': ['104006048', '104006156', '104008722', '104008723'],
#  '6704': ['103016354', '103016355'],
#  '6705': ['108001532'],
#  '6706': None,
#  '6708': None,
#  '6710': None,
#  '6711': ['103080124', '103102442', '103102443'],
#  '6712': ['103046838', '103046839'],
#  '6713': ['103055122', '103055123', '103102420'],
#  '6714': ['103066964', '103104776'],
#  '6715': ['103042174', '103042175', '103099677'],
#  '6716': ['103040776', '103067190', '103067191', '103114918', '103114919'],
#  '7791': ['103103452'],
#  '7793': ['103063616', '103103526', '103103527', '103115093'],
#  '7794': ['103064934', '103064935', '103103352', '103107240'],
#  '7795': ['103040960', '103061402', '103061403'],
#  '7796': ['103048325', '103056890', '103056891'],
#  '7797': ['103057028', '103066584', '115000412', '115000528'],
#  '7798': ['103054904'],
#  '8701': ['103116278', '103116279'],
#  '8702': ['103045528'],
#  '8704': None,
#  '8706': ['103053952', '103053964', '109002188'],
#  '9701': ['103104270', '103104271'],
#  '9702': ['103104226', '103104227'],
#  '9703': ['103055720', '106003820'],
#  '9704': ['104006714', '104006715', '106003612'],
#  '9705': ['103035560'],
#  '9706': ['103055798', '103055799', '107001442', '107001443']}

# %%
url_images = 'http://datamall2.mytransport.sg/ltaodataservice/Traffic-Imagesv2'
headers = {'AccountKey' : 'Ac8SpA/uQO22Wv5fA+lmaQ=='}
images = requests.get(url_images, headers = headers).json()
imagesdf2 = pd.DataFrame(images['value']).set_index('CameraID')
# Out:
#           Latitude   Longitude  \
# CameraID
# 1001      1.295313  103.871146
# 1002      1.319541  103.878563
# 1003      1.323957  103.872858
# 1004      1.319536  103.875067
# 1005      1.363520  103.905394
# ...            ...         ...
# 9702      1.394741  103.817971
# 9703      1.422857  103.773005
# 9704      1.422143  103.795421
# 9705      1.426277  103.787166
# 9706      1.412701  103.806427
#
#                                                   ImageLink
# CameraID
# 1001      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 1002      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 1003      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 1004      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 1005      https://dm-traffic-camera-itsc.s3.ap-southeast...
# ...                                                     ...
# 9702      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 9703      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 9704      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 9705      https://dm-traffic-camera-itsc.s3.ap-southeast...
# 9706      https://dm-traffic-camera-itsc.s3.ap-southeast...
#
# [87 rows x 3 columns]

# %%
imagesdf2.loc['1707',:]
# Out:
# Latitude                                              1.280366
# Longitude                                           103.830451
# ImageLink    https://dm-traffic-camera-itsc.s3.ap-southeast...
# Name: 1707, dtype: object

# %%
imagesdf2.loc['1707','ImageLink']
# Out:
# 'https://dm-traffic-camera-itsc.s3.ap-southeast-1.amazonaws.com/2022-11-15/12-45/1707_1244_20221115124542_559853.jpg?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEOz%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDmFwLXNvdXRoZWFzdC0xIkgwRgIhANTrNtG%2FLJhHYpWVwr8SRQbN%2FtitOAqjWt1Q4lGu7I93AiEAowxMA6uiTfgjwtO%2FeZLaeg%2FInkcFV1%2FiyZBkKoKWjH8q5AQI5f%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FARADGgwzNDA2NDUzODEzMDQiDE3c3Z1ERY5ABNTd2iq4BNIixuwXfU%2BI1CG3O%2FrGpDU2k2FooCMgfAK%2FSHXYL6D6hl4CDuZY6kO%2BQr1trPQSyoNu%2FMO8wJT3%2BTKakne2pyM9KRRjJo61nSLxL2TgnwwUG8JXPFN5krA5TIKTtJBYajXmwdG4UHkYckb5W3%2B3%2F9qZx3Y9Z65WD20L%2FNPCI%2B1jd%2BvDxh2RNv0b%2FTAtNMhPrBXPP0UNIFD%2FOQqJFXQXEK8WWeI9i%2BqArbEdCgt56h%2FOrVcvKB8MEXOcQ4FGNo9x32lbL%2Fb50eFCGHKtSRjvQ3%2FhTtTl8N8HeuPsxfbvVsg%2BboHE6uC3wNxGwNXZjqjNBpo2pgvjMQVqt5IMifUBO2w99reVICZNaH%2FRIEIhMeTh%2FsUgJSeUKQ7GmUQzpkgx3kGoCs109tV6XWX1nLwbzNfTTS3qkBa%2BWx0pK%2BvVlEMUFABH%2FLCYoKiZN3YxeVKhTX8RGuix5FQkT61BKqrNKXDrIM9kyWb6AGLTtnsJLOkQDMQdpeepSxP7SjfFRjXfY2oMEyp7kIqMS5ef75CXKiqD0imGsk2ZkmsklDBeFfWppoVnqwJHjzqtvlb7%2FnmsIw2YkTFAWkPeSia2B%2FMq5BlMN7vgYcgKHeficQtn9b%2B1N6OiC5vAaAKi7rWopicBx0EcqW1VL96ATYT2W4jmTSuCLT7CbxG34X461%2B5hi50n3B05HHQPhwOM1LmbCQqgrAQqrt49RaxnoUy9XOItv9%2FlKTTrCQAQK6v7CXsCnQgBxJklSkNBycswmabMmwY6qAFeqGSxAb3%2BmMg4oCDQZKIzPXTdWxLs1XhKTzeHmYFrM4vWrfp9FsP7NrVwVqg20Az%2F5M0T7tWdbBsHRWhCr%2BBB1ZH6ecMg1cR5C8o3LAdGWPWnzGJhYLuHEYRfLA8PPDgP2x4TjxNA8Tx5HoCHBz3Ja7APXJmgFG6hOLywu06ET%2Bfz34ol2GsOZO0KRZY%2Fm8Z%2FTU5EXkaywrdoMJJz67KLFB68KNI1EY4%3D&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20221115T044549Z&X-Amz-SignedHeaders=host&X-Amz-Expires=600&X-Amz-Credential=ASIAU6UAMAS4OSGGZXVR%2F20221115%2Fap-southeast-1%2Fs3%2Faws4_request&X-Amz-Signature=97b9796998d1f0d8ea26a47fa16f9c8cc49a98ff4aab50a7b46d9e9fd03b1722'

# %%
speedsdf.loc[['103013056',
  '103061773',
  '103103406',
  '103103407',
  '116000006',
  '116000007'], :]
# Out:
#                      RoadName RoadCategory  SpeedBand MinimumSpeed  \
# LinkID
# 103013056   JALAN BUKIT MERAH            F          5           40
# 103061773  CENTRAL EXPRESSWAY            F          5           40
# 103103406  CENTRAL EXPRESSWAY            A          8           70
# 103103407  CENTRAL EXPRESSWAY            A          8           70
# 116000006     MACALISTER ROAD            E          8           70
# 116000007     MACALISTER ROAD            E          2           10
#
#           MaximumSpeed                                           Location
# LinkID
# 103013056           49  1.2797544818379811 103.82916817881473 1.280601...
# 103061773           49  1.2793302810560436 103.82958020398998 1.280601...
# 103103406          999  1.2806016384288461 103.83045155058139 1.279879...
# 103103407          999  1.2798791493486743 103.8296926102903 1.2806016...
# 116000006          999  1.2809400798468304 103.8314402119217 1.2798566...
# 116000007           19  1.279856622402995 103.83029145890723 1.2809400...

# %% [markdown]
# # Integrating weather

# %% [markdown]
# # Uploading onto bigquery

# %%
import os
import pandas as pd
from google.cloud import bigquery
from congestion.data.params import PROJECT, DATASET, LOCAL_DATA_PATH
from congestion.data.get_data import get_images, get_speeds

# %%
os.path.join(LOCAL_DATA_PATH, 'data-speeds', 'speeds.csv')
# Out:
# '/home/mayank-soni/.lewagon/congestion/data-speeds/speeds.csv'

# %%
speedsdf = pd.read_csv(os.path.join(LOCAL_DATA_PATH, 'data-speeds', 'speeds.csv'))
# Out:
#       LinkID         RoadName RoadCategory  SpeedBand  MinimumSpeed  \
# 0  103000000        KENT ROAD            E          4            30
# 1  103000010     BUCKLEY ROAD            E          3            20
# 2  103000011     BUCKLEY ROAD            E          3            20
# 3  103000014  SHREWSBURY ROAD            E          6            50
# 4  103000015  SHREWSBURY ROAD            E          6            50
#
#    MaximumSpeed                                           Location  \
# 0            39  1.3170142376560023 103.85298052044503 1.316684...
# 1            29  1.3166507852203482 103.84102305136321 1.316912...
# 2            29  1.316912438354752 103.84022564204443 1.3166507...
# 3            59  1.3186726294030418 103.84700267615683 1.318021...
# 4            59  1.3180212058893457 103.84711392225329 1.318672...
#
#               Time
# 0  2022-11-17_0102
# 1  2022-11-17_0102
# 2  2022-11-17_0102
# 3  2022-11-17_0102
# 4  2022-11-17_0102

# %%
table = f"{PROJECT}.{DATASET}.speeds"
# Out:
# 'congestion-368810.speeds.speeds'

# %%
client = bigquery.Client(project=PROJECT)

# %%
tables = client.list_tables(f'{PROJECT}.{DATASET}')

# %%
query_job = client.query(
    """
    SELECT
      CONCAT(
        'https://stackoverflow.com/questions/',
        CAST(id as STRING)) as url,
      view_count
    FROM `bigquery-public-data.stackoverflow.posts_questions`
    WHERE tags like '%google-bigquery%'
    ORDER BY view_count DESC
    LIMIT 10"""
)

results = query_job.result()  # Waits for job to complete.
# Out:
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 query_job = client.query(
#       2     """
#       3     SELECT
#       4       CONCAT(
#       5         'https://stackoverflow.com/questions/',
#       6         CAST(id as STRING)) as url,
#       7       view_count
#       8     FROM `bigquery-public-data.stackoverflow.posts_questions`
#       9     WHERE tags like '%google-bigquery%'
#      10     ORDER BY view_count DESC
#      11     LIMIT 10"""
#      12 )
#      14 results = query_job.result()  # Waits for job to complete.
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/cloud/bigquery/client.py:3334, in Client.query(self, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry, api_method)
#    3323     return _job_helpers.query_jobs_query(
#    3324         self,
#    3325         query,
#    (...)
#    3331         job_retry,
#    3332     )
#    3333 elif api_method == enums.QueryApiMethod.INSERT:
# -> 3334     return _job_helpers.query_jobs_insert(
#    3335         self,
#    3336         query,
#    3337         job_config,
#    3338         job_id,
#    3339         job_id_prefix,
#    3340         location,
#    3341         project,
#    3342         retry,
#    3343         timeout,
#    3344         job_retry,
#    3345     )
#    3346 else:
#    3347     raise ValueError(f"Got unexpected value for api_method: {repr(api_method)}")
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/cloud/bigquery/_job_helpers.py:114, in query_jobs_insert(client, query, job_config, job_id, job_id_prefix, location, project, retry, timeout, job_retry)
#     111     else:
#     112         return query_job
# --> 114 future = do_query()
#     115 # The future might be in a failed state now, but if it's
#     116 # unrecoverable, we'll find out when we ask for it's result, at which
#     117 # point, we may retry.
#     118 if not job_id_given:
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/cloud/bigquery/_job_helpers.py:91, in query_jobs_insert.<locals>.do_query()
#      88 query_job = job.QueryJob(job_ref, query, client=client, job_config=job_config)
#      90 try:
# ---> 91     query_job._begin(retry=retry, timeout=timeout)
#      92 except core_exceptions.Conflict as create_exc:
#      93     # The thought is if someone is providing their own job IDs and they get
#      94     # their job ID generation wrong, this could end up returning results for
#      95     # the wrong query. We thus only try to recover if job ID was not given.
#      96     if job_id_given:
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/cloud/bigquery/job/query.py:1298, in QueryJob._begin(self, client, retry, timeout)
#    1278 """API call:  begin the job via a POST request
#    1279
#    1280 See
#    (...)
#    1294     ValueError: If the job has already begun.
#    1295 """
#    1297 try:
# -> 1298     super(QueryJob, self)._begin(client=client, retry=retry, timeout=timeout)
#    1299 except exceptions.GoogleAPICallError as exc:
#    1300     exc.message = _EXCEPTION_FOOTER_TEMPLATE.format(
#    1301         message=exc.message, location=self.location, job_id=self.job_id
#    1302     )
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/cloud/bigquery/job/base.py:510, in _AsyncJob._begin(self, client, retry, timeout)
#     507 # jobs.insert is idempotent because we ensure that every new
#     508 # job has an ID.
#     509 span_attributes = {"path": path}
# --> 510 api_response = client._call_api(
#     511     retry,
#     512     span_name="BigQuery.job.begin",
#     513     span_attributes=span_attributes,
#     514     job_ref=self,
#     515     method="POST",
#     516     path=path,
#     517     data=self.to_api_repr(),
#     518     timeout=timeout,
#     519 )
#     520 self._set_properties(api_response)
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/cloud/bigquery/client.py:759, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     755 if span_name is not None:
#     756     with create_span(
#     757         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     758     ):
# --> 759         return call()
#     761 return call()
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/api_core/retry.py:283, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     279 target = functools.partial(func, *args, **kwargs)
#     280 sleep_generator = exponential_sleep_generator(
#     281     self._initial, self._maximum, multiplier=self._multiplier
#     282 )
# --> 283 return retry_target(
#     284     target,
#     285     self._predicate,
#     286     sleep_generator,
#     287     self._deadline,
#     288     on_error=on_error,
#     289 )
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/api_core/retry.py:190, in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     188 for sleep in sleep_generator:
#     189     try:
# --> 190         return target()
#     192     # pylint: disable=broad-except
#     193     # This function explicitly must deal with broad exceptions.
#     194     except Exception as exc:
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/cloud/_http/__init__.py:482, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     479     data = json.dumps(data)
#     480     content_type = "application/json"
# --> 482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#     485     data=data,
#     486     content_type=content_type,
#     487     headers=headers,
#     488     target_object=_target_object,
#     489     timeout=timeout,
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
#     494     raise exceptions.from_http_response(response)
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/cloud/_http/__init__.py:341, in JSONConnection._make_request(self, method, url, data, content_type, headers, target_object, timeout, extra_api_info)
#     338     headers[CLIENT_INFO_HEADER] = self.user_agent
#     339 headers["User-Agent"] = self.user_agent
# --> 341 return self._do_request(
#     342     method, url, headers, data, target_object, timeout=timeout
#     343 )
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/cloud/_http/__init__.py:379, in JSONConnection._do_request(self, method, url, headers, data, target_object, timeout)
#     345 def _do_request(
#     346     self, method, url, headers, data, target_object, timeout=_DEFAULT_TIMEOUT
#     347 ):  # pylint: disable=unused-argument
#     348     """Low-level helper:  perform the actual API request over HTTP.
#     349
#     350     Allows batch context managers to override and defer a request.
#    (...)
#     377     :returns: The HTTP response.
#     378     """
# --> 379     return self.http.request(
#     380         url=url, method=method, headers=headers, data=data, timeout=timeout
#     381     )
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/auth/transport/requests.py:545, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     542 remaining_time = max_allowed_time
#     544 with TimeoutGuard(remaining_time) as guard:
# --> 545     self.credentials.before_request(auth_request, method, url, request_headers)
#     546 remaining_time = guard.remaining_timeout
#     548 with TimeoutGuard(remaining_time) as guard:
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/auth/credentials.py:134, in Credentials.before_request(self, request, method, url, headers)
#     130 # pylint: disable=unused-argument
#     131 # (Subclasses may use these arguments to ascertain information about
#     132 # the http request.)
#     133 if not self.valid:
# --> 134     self.refresh(request)
#     135 self.apply(headers)
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/oauth2/service_account.py:429, in Credentials.refresh(self, request)
#     427 else:
#     428     assertion = self._make_authorization_grant_assertion()
# --> 429     access_token, expiry, _ = _client.jwt_grant(
#     430         request, self._token_uri, assertion
#     431     )
#     432     self.token = access_token
#     433     self.expiry = expiry
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/oauth2/_client.py:289, in jwt_grant(request, token_uri, assertion, can_retry)
#     265 """Implements the JWT Profile for OAuth 2.0 Authorization Grants.
#     266
#     267 For more details, see `rfc7523 section 4`_.
#    (...)
#     285 .. _rfc7523 section 4: https://tools.ietf.org/html/rfc7523#section-4
#     286 """
#     287 body = {"assertion": assertion, "grant_type": _JWT_GRANT_TYPE}
# --> 289 response_data = _token_endpoint_request(
#     290     request, token_uri, body, can_retry=can_retry
#     291 )
#     293 try:
#     294     access_token = response_data["access_token"]
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/oauth2/_client.py:260, in _token_endpoint_request(request, token_uri, body, access_token, use_json, can_retry, **kwargs)
#     250 response_status_ok, response_data, retryable_error = _token_endpoint_request_no_throw(
#     251     request,
#     252     token_uri,
#    (...)
#     257     **kwargs
#     258 )
#     259 if not response_status_ok:
# --> 260     _handle_error_response(response_data, retryable_error)
#     261 return response_data
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/oauth2/_client.py:69, in _handle_error_response(response_data, retryable_error)
#      66 except (KeyError, ValueError):
#      67     error_details = json.dumps(response_data)
# ---> 69 raise exceptions.RefreshError(
#      70     error_details, response_data, retryable=retryable_error
#      71 )
#
# RefreshError: ('invalid_grant: Invalid grant: account not found', {'error': 'invalid_grant', 'error_description': 'Invalid grant: account not found'})

# %%
for table in tables:
    print("{}.{}.{}".format(table.project, table.dataset_id, table.table_id))
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 for table in tables:
#       2     print("{}.{}.{}".format(table.project, table.dataset_id, table.table_id))
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/api_core/page_iterator.py:208, in Iterator._items_iter(self)
#     206 def _items_iter(self):
#     207     """Iterator for each item returned."""
# --> 208     for page in self._page_iter(increment=False):
#     209         for item in page:
#     210             self.num_results += 1
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/api_core/page_iterator.py:244, in Iterator._page_iter(self, increment)
#     232 def _page_iter(self, increment):
#     233     """Generator of pages of API responses.
#     234
#     235     Args:
#    (...)
#     242         Page: each page of items from the API.
#     243     """
# --> 244     page = self._next_page()
#     245     while page is not None:
#     246         self.page_number += 1
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/api_core/page_iterator.py:373, in HTTPIterator._next_page(self)
#     366 """Get the next page in the iterator.
#     367
#     368 Returns:
#     369     Optional[Page]: The next page in the iterator or :data:`None` if
#     370         there are no pages left.
#     371 """
#     372 if self._has_next_page():
# --> 373     response = self._get_next_page_response()
#     374     items = response.get(self._items_key, ())
#     375     page = Page(self, items, self.item_to_value, raw_page=response)
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/api_core/page_iterator.py:432, in HTTPIterator._get_next_page_response(self)
#     430 params = self._get_query_params()
#     431 if self._HTTP_METHOD == "GET":
# --> 432     return self.api_request(
#     433         method=self._HTTP_METHOD, path=self.path, query_params=params
#     434     )
#     435 elif self._HTTP_METHOD == "POST":
#     436     return self.api_request(
#     437         method=self._HTTP_METHOD, path=self.path, data=params
#     438     )
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/cloud/bigquery/client.py:1502, in Client.list_tables.<locals>.api_request(*args, **kwargs)
#    1501 def api_request(*args, **kwargs):
# -> 1502     return self._call_api(
#    1503         retry,
#    1504         span_name="BigQuery.listTables",
#    1505         span_attributes=span_attributes,
#    1506         *args,
#    1507         timeout=timeout,
#    1508         **kwargs,
#    1509     )
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/cloud/bigquery/client.py:759, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     755 if span_name is not None:
#     756     with create_span(
#     757         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     758     ):
# --> 759         return call()
#     761 return call()
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/api_core/retry.py:283, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     279 target = functools.partial(func, *args, **kwargs)
#     280 sleep_generator = exponential_sleep_generator(
#     281     self._initial, self._maximum, multiplier=self._multiplier
#     282 )
# --> 283 return retry_target(
#     284     target,
#     285     self._predicate,
#     286     sleep_generator,
#     287     self._deadline,
#     288     on_error=on_error,
#     289 )
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/api_core/retry.py:190, in retry_target(target, predicate, sleep_generator, deadline, on_error)
#     188 for sleep in sleep_generator:
#     189     try:
# --> 190         return target()
#     192     # pylint: disable=broad-except
#     193     # This function explicitly must deal with broad exceptions.
#     194     except Exception as exc:
#
# File ~/.pyenv/versions/3.10.7/envs/congestion/lib/python3.10/site-packages/google/cloud/_http/__init__.py:494, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#    (...)
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
# --> 494     raise exceptions.from_http_response(response)
#     496 if expect_json and response.content:
#     497     return response.json()
#
# Forbidden: 403 GET https://bigquery.googleapis.com/bigquery/v2/projects/congestion-368810/datasets/speeds/tables?prettyPrint=false: Access Denied: Dataset congestion-368810:speeds: Permission bigquery.tables.list denied on dataset congestion-368810:speeds (or it may not exist).

# %%
job_config = bigquery.LoadJobConfig(autodetect=True)

# %%
client.load_table_from_dataframe(speedsdf, table, job_config = job_config)
# Out:
# LoadJob<project=congestion-368810, location=asia-southeast1, id=916f8bf8-5f4a-44fd-a6d6-756f3998c1ab>

# %%
speedsdf = pd.read_csv(os.path.join(LOCAL_DATA_PATH, 'data-speeds', 'speeds.csv'))
save_speeds_cloud(speedsdf)
table = f"{PROJECT}.{DATASET}.speeds"
client = bigquery.Client()
job_config = bigquery.LoadJobConfig(autodetect=True)
client.load_table_from_dataframe(speedsdf, table, job_config = job_config)
